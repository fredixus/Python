# %%
1+1
# Out:
# 2

# %%
from keras.applications.resnet50 import ResNet50, decode_predictions, preprocess_input
from keras.preprocessing import image
import numpy as np

import requests as re
from io import BytesIO
from PIL import Image

# %%
model = ResNet50(weights='imagenet')

# %% [markdown]
# ![](https://www.koty.pl/wp-content/uploads/2018/08/shutterstock_517111960-864x575.jpg)

# %%
url_img = "https://www.koty.pl/wp-content/uploads/2018/08/shutterstock_517111960-864x575.jpg"

# %%
#![](https://www.koty.pl/wp-content/uploads/2018/08/shutterstock_517111960-864x575.jpg)
#markdown

response = re.get(url_img)
img = Image.open( BytesIO(response.content) )

img = img.resize( (224,224) )
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21E9DE2DDA0>

# %%
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
X.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(X)

# %%
decode_predictions(y_pred, top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.19107398),
#   ('n02123159', 'tiger_cat', 0.15102488),
#   ('n02123045', 'tabby', 0.105820484)]]

# %%
beer = "https://www.estop24.pl/thumbs/w1000h1200q88/img/products/big/ubrbut.jpg?v=930cc49bdcdfbe31843b7276641646a9"
responseBeer = re.get(beer)
imgBeer = Image.open( BytesIO(responseBeer.content) )

imgBeer = imgBeer.resize( (224,224) )
imgBeer
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21E9DE02198>

# %%
Xb = image.img_to_array(imgBeer)
Xb = np.expand_dims(Xb, axis=0)
Xb.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(Xb)
decode_predictions(y_pred, top=3)
# Out:
# [[('n02823428', 'beer_bottle', 0.93047076),
#   ('n03983396', 'pop_bottle', 0.047743183),
#   ('n04557648', 'water_bottle', 0.011905476)]]

# %%
wine = "http://winomoichpodrozy.pl/sklep/348/regent-novum-wino-uniwersytetu-jagiellonskiego-w-krakowie.jpg"
responseWine = re.get(wine)
imgWine = Image.open( BytesIO(responseWine.content) )

imgWine = imgWine.resize( (224,224) )
imgWine
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21E98BA14A8>

# %%
Xw = image.img_to_array(imgWine)
Xw = np.expand_dims(Xw, axis=0)
Xw.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(Xw)
decode_predictions(y_pred, top=3)
# Out:
# [[('n02823428', 'beer_bottle', 0.55616504),
#   ('n04591713', 'wine_bottle', 0.25923392),
#   ('n07892512', 'red_wine', 0.09687123)]]

# %%
vodka = "https://alkohol-online.pl/1481-large_default/zubrowka-biala-500ml.jpg"
responseVodka = re.get(vodka)
imgVodka = Image.open( BytesIO(responseVodka.content) )

imgVodka = imgVodka.resize( (224,224) )
imgVodka
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21E98BA1518>

# %%
Xw = image.img_to_array(imgWine)
Xw = np.expand_dims(Xw, axis=0)
Xw.shape
# Out:
# (1, 224, 224, 3)

# %%
y_pred = model.predict(Xw)
decode_predictions(y_pred, top=3)
# Out:
# [[('n02823428', 'beer_bottle', 0.55616504),
#   ('n04591713', 'wine_bottle', 0.25923392),
#   ('n07892512', 'red_wine', 0.09687123)]]
